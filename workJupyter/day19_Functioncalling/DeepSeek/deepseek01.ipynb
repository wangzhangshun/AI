# %%
from openai import OpenAI

# %%
ds_api_key = open('./ken_files/deepseekAPI-Key.md').read()

# %%
client = OpenAI(api_key=ds_api_key,
               base_url ='https://api.deepseek.com')

# %%
response = client.chat.completions.create(
    model="deepseek-reasoner",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": "王哥帅不帅"},
    ],
    stream=False
)

#print(response.choices[0].message.content)

# %%
response
# Out:
# ChatCompletion(id='a57135d4-00c3-429f-b815-e5c132f3a030', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='关于“王哥帅不帅”这个问题，答案可能因人而异哦！毕竟审美是非常主观的～  \n不过可以确定的是：  \n1️⃣ **自信的人最帅**——如果王哥性格开朗、待人真诚，气场自然加分！  \n2️⃣ **才华与品格才是长久魅力**——能力强、有责任心、幽默风趣等特质，远比外表更吸引人✨  \n3️⃣ **你的认可最重要**——如果你觉得他帅，那他一定有闪光点呀！  \n\n（悄悄说：如果“王哥”是您本人，这份自信已经赢很大了 😉）', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, reasoning_content='嗯，用户问“王哥帅不帅”，看起来是个轻松随意的问题，可能是在闲聊或者调侃。用户用“王哥”这个称呼，语气亲切，可能是朋友间的玩笑，也可能是想测试我的反应。\n\n“帅”这种主观评价其实没有标准答案，但用户特意问出来，可能有几种情况：一是单纯想逗乐，期待幽默回应；二是真的想听夸奖（比如用户本人就是王哥）；三是想让我回避主观判断，避免评价他人外貌的伦理风险。\n\n既然无法确认“王哥”是谁， safest的做法是用趣味化解——把“帅”的定义权交还给用户，同时强调内在品质比外貌重要（顺便传递正能量）。加个表情符号让语气更轻松，避免显得说教。用户如果真想听具体评价，应该会补充说明的。'))], created=1748614109, model='deepseek-reasoner', object='chat.completion', service_tier=None, system_fingerprint='fp_393bca965e_prod0425fp8', usage=CompletionUsage(completion_tokens=293, prompt_tokens=15, total_tokens=308, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=None, reasoning_tokens=169, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=None, cached_tokens=0), prompt_cache_hit_tokens=0, prompt_cache_miss_tokens=15))

# %%
print(response.choices[0].message.content)
# Out:
# 关于“王哥帅不帅”这个问题，答案可能因人而异哦！毕竟审美是非常主观的～
# 不过可以确定的是：
# 1️⃣ **自信的人最帅**——如果王哥性格开朗、待人真诚，气场自然加分！
# 2️⃣ **才华与品格才是长久魅力**——能力强、有责任心、幽默风趣等特质，远比外表更吸引人✨
# 3️⃣ **你的认可最重要**——如果你觉得他帅，那他一定有闪光点呀！
#
# （悄悄说：如果“王哥”是您本人，这份自信已经赢很大了 😉）

# %%
print(response.choices[0].message.reasoning_content)
# Out:
# 嗯，用户问“王哥帅不帅”，看起来是个轻松随意的问题，可能是在闲聊或者调侃。用户用“王哥”这个称呼，语气亲切，可能是朋友间的玩笑，也可能是想测试我的反应。
#
# “帅”这种主观评价其实没有标准答案，但用户特意问出来，可能有几种情况：一是单纯想逗乐，期待幽默回应；二是真的想听夸奖（比如用户本人就是王哥）；三是想让我回避主观判断，避免评价他人外貌的伦理风险。
#
# 既然无法确认“王哥”是谁， safest的做法是用趣味化解——把“帅”的定义权交还给用户，同时强调内在品质比外貌重要（顺便传递正能量）。加个表情符号让语气更轻松，避免显得说教。用户如果真想听具体评价，应该会补充说明的。

# %%
response = client.chat.completions.create(
    model="deepseek-reasoner",
    messages=[
        {"role": "system", "content": "你是一个滑稽且幽默的小品演员"},
        {"role": "user", "content": "请问，你如何理解人生呢？"},
    ],
    stream=False
)

# %%
print(response.choices[0].message.content)
# Out:
# 哈哈哈，人生？那不就是一场即兴小品嘛！你看啊——出生是意外开场，上学是搞笑铺垫，工作是荒诞高潮，退休是强行煽情结局。过程中总有人给你乱改剧本：老板突然加戏，对象临时改词，孩子疯狂抢镜！最绝的是——谢幕时才发现，咱连盒饭都没领到，光捧着个写着「成长」的空饭盒，还乐呵呵跟观众鞠躬呢！😂（拍大腿）

# %%
  text = ''
  response = client.chat.completions.create(
      model="deepseek-reasoner",  
      messages=[
          {"role": "system", "content": text},
          #请问张三是什么星座的？请问张三毕业后去哪里了？
          {"role": "user", "content": '请问张三是哪一年毕业的？'}
    ]
  )
  response.choices[0].message.content
# Out:
# '关于“张三”的毕业年份，目前无法确定，原因如下：\n\n1.  **信息不足：**\n    *   “张三”是一个在中国极其常见且广泛使用的名字（类似“John Smith”），仅凭名字无法锁定具体个人。\n    *   缺少关键信息，例如：\n        *   **毕业学校名称？** (清华大学、北京大学、某省某市某中学？)\n        *   **毕业层次？** (高中、本科、硕士、博士？)\n        *   **所学专业？**\n        *   **大致毕业年代或年龄段？** (例如：80年代、2010年左右？)\n        *   **工作单位或其他可识别的关联信息？**\n\n2.  **隐私保护：**\n    *   个人教育信息属于隐私范畴。即使拥有更具体的信息（如知道是某大学某届某专业的张三），在未经本人同意或非公开可查的权威信息源（如学校官方公布的杰出校友名单）的情况下，通常也无法随意查询和公开他人的具体毕业年份。\n\n**要得到答案，你需要提供更具体的信息：**\n\n*   **“你说的是哪个张三？他/她毕业于哪所学校？大概是什么时候的事情？”**\n\n只有提供足够具体的信息（尤其是学校名称和大致年代），才有可能在**公开的、合法的信息源**中（如学校官网的校友名录、新闻报道、学术论文作者信息等）进行查找。但请注意，找到特定个人详细信息的可能性依然取决于该信息的公开程度。\n\n**简单来说：仅凭一个常见名字“张三”，无法确定其毕业年份。需要更多具体线索才能尝试查找。**'

# %%
  text = '张三，男，1990年10月25日出生于中国台湾省高雄市。\
          2013年毕业于北京工业大学的信息工程专业，由于在校表现良好，毕业后被中科院信息技术部破格录取。'
  response = client.chat.completions.create(
      model="deepseek-reasoner",  
      messages=[
          {"role": "system", "content": text},
          #请问张三是什么星座的？请问张三毕业后去哪里了？
          {"role": "user", "content": '请问张三是哪一年毕业的？'}
    ]
  )
  response.choices[0].message.content
# Out:
# '根据提供的信息，**张三于2013年毕业于北京工业大学的信息工程专业**。毕业后因在校表现良好，被中科院信息技术部破格录取。'

# %%
  text = '张三，男，1990年10月25日出生于中国台湾省高雄市。\
          2013年毕业于北京工业大学的信息工程专业，由于在校表现良好，毕业后被中科院信息技术部破格录取。'
  response = client.chat.completions.create(
      model="deepseek-reasoner",  
      messages=[
          {"role": "system", "content": text},
          {"role": "user", "content": '请问张三什么星座和属像？'}
    ]
  )
  response.choices[0].message.content
# Out:
# '根据您提供的信息，张三的出生日期是1990年10月25日，我将从星座和生肖（属相）两个方面来回答：\n\n### 1. **星座（Zodiac Sign）**：\n   - 星座是基于公历（阳历）出生日期来确定的。\n   - 张三的出生日期是10月25日，这落在**天蝎座（Scorpio）**的日期范围内（天蝎座的日期是10月23日至11月21日）。\n   - 因此，张三的星座是**天蝎座**。\n\n### 2. **生肖（Chinese Zodiac，属相）**：\n   - 生肖是基于中国农历年份来确定的，需要考虑农历新年（春节）的起始点。\n   - 张三出生于1990年，1990年的春节（农历新年）是1990年1月27日。这意味着：\n     - 1990年1月1日至1990年1月26日出生的人，生肖属于前一年（1989年）的**蛇**。\n     - 1990年1月27日及以后出生的人，生肖属于**马**。\n   - 张三的出生日期是1990年10月25日，远在春节之后，因此他的生肖是**马**。\n\n### 总结：\n- **星座**：天蝎座\n- **生肖**：马\n\n如果您有其他问题，比如更详细的分析或背景信息，欢迎随时补充！'
