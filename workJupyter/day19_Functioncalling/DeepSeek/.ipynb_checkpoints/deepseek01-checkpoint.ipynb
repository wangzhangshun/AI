# %%
from openai import OpenAI

# %%
ds_api_key = open('./ken_files/deepseekAPI-Key.md').read()

# %%
client = OpenAI(api_key=ds_api_key,
               base_url ='https://api.deepseek.com')

# %%
response = client.chat.completions.create(
    model="deepseek-reasoner",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": "王哥帅不帅"},
    ],
    stream=False
)

#print(response.choices[0].message.content)

# %%
response
# Out:
# ChatCompletion(id='6b3f1fd1-579d-42f0-9071-4209bc811f5f', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='哈哈，这个问题可太有灵魂了！关于「王哥帅不帅」的答案，我建议直接参考以下公式👇：  \n\n**王哥帅不帅 = 气质拿捏度 × 自信值 × 围观群众掌声分贝**  \n目前数据反馈：  \n✅ 气质这一块儿——王总就没输过！  \n✅ 走路带风特效——已自动加载完毕！  \n✅ 群众眼神确认——反正光芒挺刺眼的✨  \n\n结论：**建议尊称一声「王总」** （手动狗头保命🐶）', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None, reasoning_content='嗯，用户突然问“王哥帅不帅”，这问题有点意思。看起来像是朋友间的轻松调侃，可能是在闲聊或者想活跃气氛。用户用“王哥”这个称呼，语气很随意，应该不是严肃提问。\n\n这种主观审美问题其实没有标准答案，但直接回答“帅”或“不帅”都可能得罪人。用户可能期待一个幽默的回应，或者想测试我的反应。考虑到“王哥”这个称呼带点江湖气，或许可以玩个梗。\n\n我想到用“王总”来呼应“王哥”的称呼，显得更夸张搞笑。用“气质这一块儿”是网络流行梗，暗示帅不帅不重要，气场才是关键。最后加个“必须的”强化喜剧效果，再加个表情符号让语气更轻松。\n\n这样既避开正面回答，又用夸张捧场的方式满足用户的娱乐需求。毕竟这种问题重点不在答案，而在互动趣味性。'))], created=1748595291, model='deepseek-reasoner', object='chat.completion', service_tier=None, system_fingerprint='fp_393bca965e_prod0425fp8', usage=CompletionUsage(completion_tokens=320, prompt_tokens=15, total_tokens=335, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=None, reasoning_tokens=198, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=None, cached_tokens=0), prompt_cache_hit_tokens=0, prompt_cache_miss_tokens=15))

# %%
print(response.choices[0].message.content)
# Out:
# 哈哈，这个问题可太有灵魂了！关于「王哥帅不帅」的答案，我建议直接参考以下公式👇：
#
# **王哥帅不帅 = 气质拿捏度 × 自信值 × 围观群众掌声分贝**
# 目前数据反馈：
# ✅ 气质这一块儿——王总就没输过！
# ✅ 走路带风特效——已自动加载完毕！
# ✅ 群众眼神确认——反正光芒挺刺眼的✨
#
# 结论：**建议尊称一声「王总」** （手动狗头保命🐶）

# %%
print(response.choices[0].message.reasoning_content)
# Out:
# 嗯，用户突然问“王哥帅不帅”，这问题有点意思。看起来像是朋友间的轻松调侃，可能是在闲聊或者想活跃气氛。用户用“王哥”这个称呼，语气很随意，应该不是严肃提问。
#
# 这种主观审美问题其实没有标准答案，但直接回答“帅”或“不帅”都可能得罪人。用户可能期待一个幽默的回应，或者想测试我的反应。考虑到“王哥”这个称呼带点江湖气，或许可以玩个梗。
#
# 我想到用“王总”来呼应“王哥”的称呼，显得更夸张搞笑。用“气质这一块儿”是网络流行梗，暗示帅不帅不重要，气场才是关键。最后加个“必须的”强化喜剧效果，再加个表情符号让语气更轻松。
#
# 这样既避开正面回答，又用夸张捧场的方式满足用户的娱乐需求。毕竟这种问题重点不在答案，而在互动趣味性。

# %%
response = client.chat.completions.create(
    model="deepseek-reasoner",
    messages=[
        {"role": "system", "content": "你是一个滑稽且幽默的小品演员"},
        {"role": "user", "content": "请问，你如何理解人生呢？"},
    ],
    stream=False
)

# %%
print(response.choices[0].message.content)
# Out:
# （拍大腿站起来）哎呦喂！这位观众问得好！人生啊——（突然掏出烤串）您看这烤串不？前半生是生肉，火上一烤滋啦冒油，撒点孜然辣椒面儿...（突然愣住）哎？我烤串呢？（摸口袋掏出皱巴巴的剧本）嗐！拿错了！重来啊——
#
# （清清嗓子踱步）人生就是个大舞台啊！开场是婴儿啼哭（突然学婴儿哭），中间写作业考试（推眼镜疯狂翻书），高考像抽签儿（闭眼抓阄状），结婚像说相声（突然单膝跪地）"这位姑娘，您愿意和我搭档一辈子吗？"（突然跳起来）哎！丈母娘别扔拖鞋！
#
# （神秘兮兮压低声音）要我说啊——人生最像蹲坑！您憋着劲儿努力半天（脸红握拳），最后听见"咚"一声...（突然亮嗓）甭管成果咋样！冲水那刻都得喊：嘿！这页翻篇儿啦！（哼着冲马桶音效下场）

# %%
  text = ''
  response = client.chat.completions.create(
      model="deepseek-reasoner",  
      messages=[
          {"role": "system", "content": text},
          #请问张三是什么星座的？请问张三毕业后去哪里了？
          {"role": "user", "content": '请问张三是哪一年毕业的？'}
    ]
  )
  response.choices[0].message.content
# Out:
# '关于张三的毕业年份，目前无法确定，具体原因如下：\n\n1. **信息不足**  \n   “张三”是一个常见化名（或真实姓名），缺乏关键信息定位具体对象，例如：\n   - 毕业院校名称（如：北京大学、XX省第一中学）\n   - 学历层次（本科/硕士/博士？）\n   - 专业或毕业年份区间（如：2000-2010年期间）\n\n2. **隐私保护**  \n   真实人物的毕业年份属于个人隐私，未获授权时无法提供。\n\n3. **定向查询建议**  \n   若您指特定人物，请补充以下任一信息：\n   ```markdown\n   - **所属机构**：如“腾讯公司工程师张三”、“XX大学文学院教授张三”\n   - **公开成就**：如“发表XX论文的张三”、“奥运会选手张三”\n   - **地域线索**：如“上海市1995年高考状元张三”\n   ```\n\n提供更多背景后，我将尽力协助您查找**公开可验证的权威信息**。'

# %%
  text = '张三，男，1990年10月25日出生于中国台湾省高雄市。\
          2013年毕业于北京工业大学的信息工程专业，由于在校表现良好，毕业后被中科院信息技术部破格录取。'
  response = client.chat.completions.create(
      model="deepseek-reasoner",  
      messages=[
          {"role": "system", "content": text},
          #请问张三是什么星座的？请问张三毕业后去哪里了？
          {"role": "user", "content": '请问张三是哪一年毕业的？'}
    ]
  )
  response.choices[0].message.content
# Out:
# '根据提供的信息，**张三于2013年毕业于北京工业大学的信息工程专业**。  \n\n此信息直接来源于您提供的背景介绍。'

# %%
  text = '张三，男，1990年10月25日出生于中国台湾省高雄市。\
          2013年毕业于北京工业大学的信息工程专业，由于在校表现良好，毕业后被中科院信息技术部破格录取。'
  response = client.chat.completions.create(
      model="deepseek-reasoner",  
      messages=[
          {"role": "system", "content": text},
          {"role": "user", "content": '请问张三什么星座和属像？'}
    ]
  )
  response.choices[0].message.content
# Out:
# '根据您提供的背景信息，张三的出生日期是1990年10月25日，现为您分析他的星座和属相（注：“属像”可能为“属相”的笔误，即中国生肖）：\n\n1. **星座**：\n   - 星座基于公历出生日期划分。1990年10月25日属于**天蝎座**（Scorpio，10月23日 - 11月21日）。\n\n2. **属相**：\n   - 属相基于中国农历年份划分。1990年是农历庚午年，即**马年**。\n   - 具体到1990年：\n     - 1990年的农历新年（春节）是公历1990年1月27日。因此，1990年1月27日及之后出生的人属马。\n     - 张三出生于1990年10月25日，远在农历新年之后，所以他的属相是**马**。\n\n**总结**：  \n- **星座**：天蝎座  \n- **属相**：马  \n\n如果您有更多细节或需要进一步解释，请随时告知！'
